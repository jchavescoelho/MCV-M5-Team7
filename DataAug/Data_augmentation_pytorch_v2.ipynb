# %% [markdown]
# <a href="https://colab.research.google.com/github/jchavescoelho/MCV-M5-Team7/blob/Data_aug/Data_augmentation_pytorch_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data augmentation for pytorch**

# %%
#Data augmentation
# !pip3 install 'torch'
# !pip3 install 'torchvision'
# !pip3 install --no-cache-dir -I 'pillow==5.1.0'

# Restart Kernel
# This workaround is needed to properly upgrade PIL on Google Colab.
import os
os._exit(00)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.7.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch) (1.19.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.8.2+cu101)
# Requirement already satisfied: torch==1.7.1 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.7.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->torchvision) (3.7.4.3)
# Collecting pillow==5.1.0
#   Downloading https://files.pythonhosted.org/packages/89/b8/2f49bf71cbd0e9485bb36f72d438421b69b7356180695ae10bd4fd3066f5/Pillow-5.1.0.tar.gz (14.3MB)
#      |████████████████████████████████| 14.3MB 21.8MB/s
# Building wheels for collected packages: pillow
#   Building wheel for pillow (setup.py) ... done
#   Created wheel for pillow: filename=Pillow-5.1.0-cp37-cp37m-linux_x86_64.whl size=1075705 sha256=e1e3f5802e1c1b07005aac1960737382d4fe0ec1cb9e59488a6c48f8a704b8e1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a46b579f/wheels/75/85/02/24999a010ea6902deeb670352d8cb50301a74f2ba0c8ced944
# Successfully built pillow
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: pillow
# Successfully installed pillow-7.0.0

# %%
import PIL
import numpy as np
import torch
import torchvision
print("Done!")
# Out:
# Done!

# %%
#Show dataset
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['image.interpolation'] = 'nearest'
mpl.rcParams['figure.figsize'] = 15, 25

def show_dataset(dataset, n=6):
  img = np.vstack((np.hstack((np.asarray(dataset[i][0]) for _ in range(n)))
                   for i in range(len(dataset))))
  plt.imshow(img)
  plt.axis('off')
  print("Done!")

# %%
#Cuda GPU
import torch
print ('Available devices ', torch.cuda.device_count())
print ('Current cuda device ', torch.cuda.current_device())
# Out:
# Available devices  1
# Current cuda device  0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
'''
torch.cuda.set_device(device=gpu_id)
model.cuda()
inputs = inputs.cuda()
targets = targets.cuda()

#Numpy cannot work on CUDA Tensors, you need to
#send them to CPU before performing any operation on
#numpy:

var_cpu = var_gpu.cpu()

#Once all required operations on numpy have been
#done, remember to transform your data again to
#CUDA Tensors:
var_gpu = var_cpu.cuda()
'''
# Out:
# '\ntorch.cuda.set_device(device=gpu_id)\nmodel.cuda()\ninputs = inputs.cuda()\ntargets = targets.cuda()\n\n#Numpy cannot work on CUDA Tensors, you need to\n#send them to CPU before performing any operation on\n#numpy:\n\nvar_cpu = var_gpu.cpu()\n\n#Once all required operations on numpy have been\n#done, remember to transform your data again to\n#CUDA Tensors:\nvar_gpu = var_cpu.cuda()\n'

# %%
import torch
import torchvision
import torchvision.transforms as transforms

import PIL
import numpy as np


import torch.nn as nn
import torch.nn.functional as F
print("Done!")
# Out:
# Done!

# %% [markdown]
# # Training with Data augmentation

# %%
#Transforms: 

transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((32,32)),
    torchvision.transforms.ColorJitter(hue=.05, saturation=.05),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])
print(transforms)
# Out:
# Compose(
#     Resize(size=(32, 32), interpolation=PIL.Image.BILINEAR)
#     ColorJitter(brightness=None, contrast=None, saturation=[0.95, 1.05], hue=[-0.05, 0.05])
#     RandomHorizontalFlip(p=0.5)
#     RandomRotation(degrees=[-20.0, 20.0], resample=2, expand=False)
#     ToTensor()
#     Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
# )

# %%
#Full Data 
dataset_train = torchvision.datasets.ImageFolder('/content/drive/MyDrive/UAB_M3/MIT_split/train', 
transform=transforms)
print(dataset_train)

dataset_test = torchvision.datasets.ImageFolder('/content/drive/MyDrive/UAB_M3/MIT_split/test', 
transform=transforms)
print(dataset_test)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1881
#     Root location: /content/drive/MyDrive/UAB_M3/MIT_split/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(32, 32), interpolation=PIL.Image.BILINEAR)
#                ColorJitter(brightness=None, contrast=None, saturation=[0.95, 1.05], hue=[-0.05, 0.05])
#                RandomHorizontalFlip(p=0.5)
#                RandomRotation(degrees=[-20.0, 20.0], resample=2, expand=False)
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )
# Dataset ImageFolder
#     Number of datapoints: 807
#     Root location: /content/drive/MyDrive/UAB_M3/MIT_split/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(32, 32), interpolation=PIL.Image.BILINEAR)
#                ColorJitter(brightness=None, contrast=None, saturation=[0.95, 1.05], hue=[-0.05, 0.05])
#                RandomHorizontalFlip(p=0.5)
#                RandomRotation(degrees=[-20.0, 20.0], resample=2, expand=False)
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
#Trainloader

trainloader = torch.utils.data.DataLoader(dataset_train, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(dataset_test, batch_size=32,
                                         shuffle=False, num_workers=2)

classes = ('coast', 'forest', 'highway', 'inside_city',
           'mountain', 'Opencountry', 'street', 'tallbuilding')


print(trainloader)
print(testloader)
print(classes)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f3df1acde50>
# <torch.utils.data.dataloader.DataLoader object at 0x7f3df1acdd10>
# ('coast', 'forest', 'highway', 'inside_city', 'mountain', 'Opencountry', 'street', 'tallbuilding')

# %%
import matplotlib.pyplot as plt
import numpy as np


# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
print("dataiter",dataiter)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# dataiter <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f3de8fcc150>
# highway Opencountry coast forest

# %%
#Creating network
#


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        #x = x.view(x.size(0), 16*224*224)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %%
#Define a Loss function and optimizer
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
#Train the network
for epoch in range(100):  # loop over the dataset multiple times

    running_loss = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Finished Training')
# Out:
# Finished Training

# %%
PATH = './data_lali_m5.pth'
torch.save(net.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:  coast coast coast coast

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:  forest coast inside_city coast

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the '+str(len(dataset_train))+' test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 1881 test images: 71 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(len(classes)):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of coast : 62 %
# Accuracy of forest : 81 %
# Accuracy of highway : 75 %
# Accuracy of inside_city : 87 %
# Accuracy of mountain : 41 %
# Accuracy of Opencountry : 43 %
# Accuracy of street : 100 %
# Accuracy of tallbuilding : 81 %
